# %% [markdown]
# # Notebook to illustrate the test param files

# %%
from pathlib import Path
from IPython.display import display, Markdown
import os
import Visualize as VS
import matplotlib.pyplot as plt
from more_itertools import flatten

# %% [markdown]
# # Test Patterns

# %% [markdown]
# ### Vincular

# %%
shaded_points = VS.vincularMesh(1,4) + [(2,1)]
VS.visualize([1,3,2], shaded_points)
print(VS.vincularMesh(1,4))
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3)]

# %% [markdown]
# ### Bivincular mixed

# %%
shaded_points = [(0,0),(1,0),(2,0),(3,0),(1,1),(1,2),(1,3),(0,2),(2,2),(3,2),(3,1)]
VS.visualize([1,3,2], shaded_points)

# %% [markdown]
# ### Consecutive mixed

# %%
shaded_points = [(1,y) for y in range(0,4)] + [(2,y) for y in range(0,4)] + [(3,2)]
VS.visualize([1,3,2], shaded_points)
print (shaded_points)
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3), (3, 2)]

# %% [markdown]
# ### Box mixed

# %% [markdown]
# ## Error / Bug / Inconsistency
#
# - There seems to be a bug in the original repo, or some type of typo.
# - There is essentially no difference in performance between the box pattern and mesh.

# %%
shaded_points = [(1,y) for y in range(1,3)] + [(2,y) for y in range(0,4)]
VS.visualize([1,3,2], shaded_points)
# This one can be interesting as: a box + mesh | vicular + mesh | vincular + box

# %%
shaded_points = [(0,0),(1,0),(2,0),(3,0),(1,1),(1,2),(1,3),(0,2),(2,2),(3,2)] + [(2,3), (3,1)]
VS.visualize([1,3,2], shaded_points)

# %% [markdown]
# ## Thoughts on consecutive, vincular and bivincular models
#
# - There doesn't seem to be much of a difference between performance of these models. But there is a little bit of gain in using
# the more confined model.

# %% [markdown]
# # Other patterns

# %%
shaded_points = VS.vincularMesh(1,5) + [(2,1), (3,2), (0,2), (2,3)]
VS.visualize([1,3,2], shaded_points)
print (shaded_points)
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 1), (3, 2), (0, 2), (2, 3)]

# %%
shaded_points = [(1,y) for y in range(0,4)] + [(2,y) for y in range(0,4)] + [(3,y) for y in range(0,4)] + [(4,2), (0,1)]
VS.visualize([1,4,2,3], shaded_points)
print (shaded_points)
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3), (3, 0), (3, 1), (3, 2), (3, 3), (4, 2), (0, 1)]
