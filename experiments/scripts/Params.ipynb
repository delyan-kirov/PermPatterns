# %% [markdown]
# # Notebook to illustrate the test param files

# %%
from pathlib import Path
from IPython.display import display, Markdown
import os
import Visualize as VS
import matplotlib.pyplot as plt
from more_itertools import flatten

# %% [markdown]
# # New patterns

# %% [markdown]
# ### Vincular

# %%
shaded_points = VS.vincularMesh(1,4) + [(2,1)]
VS.visualize([1,3,2], shaded_points)
print(VS.vincularMesh(1,4))
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3)]

# %% [markdown]
# ### Bivincular mixed

# %%
shaded_points = [(0,0),(1,0),(2,0),(3,0),(1,1),(1,2),(1,3),(0,2),(2,2),(3,2)]
VS.visualize([1,3,2], shaded_points)

# %% [markdown]
# ### Consecutive mixed

# %%
shaded_points = [(1,y) for y in range(0,4)] + [(2,y) for y in range(0,4)] + [(3,2)]
VS.visualize([1,3,2], shaded_points)
print (shaded_points)
# Out:
# [(1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3), (3, 2)]

# %% [markdown]
# ### Box mixed

# %%
shaded_points = [(1,y) for y in range(1,3)] + [(2,y) for y in range(1,3)]
VS.visualize([1,3,2], shaded_points)

# %% [markdown]
# Some thoughts
# - The first few can easily be extended, the box meshes need to be given some other way to test bigger patterns
# - Still it might be nice to see what happens with increasing the sequence anyway.

# %%
shaded_points = [(1,y) for y in range(1,3)] + [(2,y) for y in range(0,4)]
VS.visualize([1,3,2], shaded_points)
# This one can be interesting as: a box + mesh | vicular + mesh | vincular + box

# %%
shaded_points = [(1,y) for y in range(1,3)] + [(2,y) for y in range(1,3)] + [(0,1)]
VS.visualize([1,3,2], shaded_points)
# Could be interesting to see of moving the box changes anything
print (shaded_points)
# Out:
# [(1, 1), (1, 2), (2, 1), (2, 2), (0, 1)]

# %%
shaded_points = [(0,0),(1,0),(2,0),(3,0),(1,1),(1,2),(1,3),(0,2),(2,2),(3,2)] + [(2,3)]
VS.visualize([1,3,2], shaded_points)
